# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
music = pd.read_csv('99_19_songs.csv')
music.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1            artist_name release_date  \
# 0           0             0                    TLC   1999-02-23
# 1           1             1              blink-182   1999-06-01
# 2           2             2            Smash Mouth   1999-01-01
# 3           3             3        Destiny's Child   1999-07-27
# 4           4             4  Red Hot Chili Peppers   1999-06-08
#
#              track_name                track_id  popularity  acousticness  \
# 0             No Scrubs  1KGi9sZVMeszgZOWivFpxs          81        0.0251
# 1  All The Small Things  2m1hi0nfMR9vdGC8UcrnwU          80        0.0103
# 2              All Star  3cfOd4CMv2snFaKAnMdnvK          81        0.0319
# 3           Say My Name  7H6ev70Weq6DdpZyyTmUXk          78        0.2730
# 4       Californication  48UPSzbZjgc449aqz8bxox          82        0.0021
#
#    danceability  duration_ms  energy  instrumentalness  key  liveness  \
# ...

# %%
music['year'] = music['release_date'].str[:4]
music = music[['artist_name', 'release_date', 'year', 'track_name', 'track_id', 'popularity', 'acousticness', 'danceability',
              'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 
              'tempo', 'time_signature', 'valence']]
music.head()
# Out:
#              artist_name release_date  year            track_name  \
# 0                    TLC   1999-02-23  1999             No Scrubs
# 1              blink-182   1999-06-01  1999  All The Small Things
# 2            Smash Mouth   1999-01-01  1999              All Star
# 3        Destiny's Child   1999-07-27  1999           Say My Name
# 4  Red Hot Chili Peppers   1999-06-08  1999       Californication
#
#                  track_id  popularity  acousticness  danceability  \
# 0  1KGi9sZVMeszgZOWivFpxs          81        0.0251         0.743
# 1  2m1hi0nfMR9vdGC8UcrnwU          80        0.0103         0.434
# 2  3cfOd4CMv2snFaKAnMdnvK          81        0.0319         0.731
# 3  7H6ev70Weq6DdpZyyTmUXk          78        0.2730         0.713
# 4  48UPSzbZjgc449aqz8bxox          82        0.0021         0.592
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       214400   0.675          0.000717    8    0.0685    -4.267     0
# ...

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201707 entries, 0 to 201706
# Data columns (total 19 columns):
# artist_name         201707 non-null object
# release_date        201707 non-null object
# year                201707 non-null object
# track_name          201707 non-null object
# track_id            201707 non-null object
# popularity          201707 non-null int64
# acousticness        201707 non-null float64
# danceability        201707 non-null float64
# duration_ms         201707 non-null int64
# energy              201707 non-null float64
# instrumentalness    201707 non-null float64
# key                 201707 non-null int64
# liveness            201707 non-null float64
# loudness            201707 non-null float64
# mode                201707 non-null int64
# speechiness         201707 non-null float64
# tempo               201707 non-null float64
# time_signature      201707 non-null int64
# valence             201707 non-null float64
# ...

# %%
# music.corr(method = 'pearson')

# %%
# sns.heatmap(music.corr(), cbar=False, linewidths=.5, annot = True, vmin = 0, vmax = 1)

# %%
sns.pairplot(music, 
             x_vars = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
                       'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence'],
             y_vars = ['popularity'], 
             kind = 'reg', plot_kws = {'line_kws':{'color':'pink'},'scatter_kws': {'alpha' : 0.01}})

# %%
sns.distplot(music['acousticness'], color = 'm')

# %%
sns.distplot(music['danceability'], color = 'g')

# %%
sns.distplot(music['duration_ms'], color = 'r')

# %%
sns.distplot(music['energy'], color = 'c')

# %%
sns.distplot(music['instrumentalness'], color = 'b')

# %%
sns.distplot(music['key'], color = 'r')

# %%
sns.distplot(music['liveness'], color = 'g')

# %%
sns.distplot(music['loudness'], color = 'y')

# %%
sns.distplot(music['mode'], color = 'b')

# %%
sns.distplot(music['speechiness'], color = 'c')

# %%
sns.distplot(music['tempo'], color = 'y')

# %%
sns.distplot(music['time_signature'], color = 'g')

# %%
sns.distplot(music['valence'], color = 'm')

# %%
# music_duration = music[music['duration_ms'] < 600000]
# music_duration

# %%
sns.distplot(music['duration_ms'], color = 'b')

# %%
# music_reject = music[(music['danceability'] <= 0.3) | (music['danceability'] >= 0.8) | (music['acousticness'] <= 0) | 
#                (music['acousticness'] >= 0.4) | (music['energy'] <= 0.3) | (music['energy'] >= 1) | (music['loudness'] <= -20) |
#                (music['instrumentalness'] >= 0.8) | (music['tempo'] <= 50) | (music['tempo'] >= 200) | (music['liveness'] >= 0.4) |
#                (music['duration_ms'] >= 400000) | (music['duration_ms'] <= 100000) | (music['speechiness'] >= 0.2)]
                                                                                                   
# music_reject

# %%
music_accept = pd.DataFrame()
music_accept = music[(music['danceability'] >= 0.3) & (music['danceability'] <= 0.8) & (music['acousticness'] >= 0) &
               (music['acousticness'] <= 0.4) & (music['energy'] >= 0.3) & (music['energy'] <= 1) & (music['loudness'] >= -20) &
               (music['instrumentalness'] <= 0.8) & (music['tempo'] >= 50) & (music['tempo'] <= 200) & (music['liveness'] <= 0.4) &
               (music['duration_ms'] <= 400000) & (music['duration_ms'] >= 100000) & (music['speechiness'] <= 0.2)]
                                                                                                   
music_accept
# Out:
#                   artist_name release_date  year                   track_name  \
# 0                         TLC   1999-02-23  1999                    No Scrubs
# 2                 Smash Mouth   1999-01-01  1999                     All Star
# 3             Destiny's Child   1999-07-27  1999                  Say My Name
# 4       Red Hot Chili Peppers   1999-06-08  1999              Californication
# 5                   blink-182   1999-06-01  1999         What's My Age Again?
# ...                       ...          ...   ...                          ...
# 201692           Hayden James   2019-06-14  2019              Better Together
# 201700                 R.E.M.   2019-11-01  2019  Crush With Eyeliner - Remix
# 201701       Cali Y El Dandee   2019-02-13  2019                   Ay Corazón
# 201703          Reese LAFLARE   2019-11-08  2019                   Masquerade
# 201705         Greyson Chance   2019-11-08  2019                        Boots
#
# ...

# %%
# music_accept = pd.DataFrame()
# music_accept = music[(music['danceability'] >= 0.3) & (music['danceability'] <= 0.8) | (music['acousticness'] >= 0) &
#                (music['acousticness'] <= 0.4) | (music['energy'] >= 0.3) & (music['energy'] <= 1) | (music['loudness'] >= -20) |
#                (music['instrumentalness'] <= 0.8) | (music['tempo'] >= 50) & (music['tempo'] <= 200) | (music['liveness'] <= 0.4) |
#                (music['duration_ms'] <= 400000) & (music['duration_ms'] >= 100000) | (music['speechiness'] <= 0.2)]
# music_accept

# %%
sns.pairplot(music_accept,  
             x_vars = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
                       'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence'],
             y_vars = ['popularity'], 
             kind = 'reg', plot_kws = {'line_kws':{'color':'pink'},'scatter_kws': {'alpha' : 0.01}})

# %%
# music_accept.corr(method = 'pearson')

# %%
# sns.heatmap(music_accept.corr(), cbar=False, linewidths=.5, annot = True, vmin = 0, vmax = 1)

# %%
music_genre = pd.read_csv('tracks.csv')
music_genre
# Out:
#         Unnamed: 0            artist_name release_date            track_name  \
# 0                0                    TLC   1999-02-23             No Scrubs
# 1                1              blink-182   1999-06-01  All The Small Things
# 2                2            Smash Mouth   1999-01-01              All Star
# 3                3        Destiny's Child   1999-07-27           Say My Name
# 4                4  Red Hot Chili Peppers   1999-06-08       Californication
# ...            ...                    ...          ...                   ...
# 201702      201702                 Pixote   2019-11-01                Nuance
# 201703      201703          Reese LAFLARE   2019-11-08            Masquerade
# 201704      201704               Slipknot   2019-08-09               My Pain
# 201705      201705         Greyson Chance   2019-11-08                 Boots
# 201706      201706             Pathfinder   2019-08-10           The Mystery
#
# ...

# %%
music_genre['year'] = music_genre['release_date'].str[:4]
music_genre = music_genre[['artist_name', 'release_date', 'year', 'track_name', 'track_id', 'popularity', 'acousticness', 'danceability',
              'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'speechiness', 
              'tempo', 'time_signature', 'valence', 'Genres']]
music_genre.head()
# Out:
#              artist_name release_date  year            track_name  \
# 0                    TLC   1999-02-23  1999             No Scrubs
# 1              blink-182   1999-06-01  1999  All The Small Things
# 2            Smash Mouth   1999-01-01  1999              All Star
# 3        Destiny's Child   1999-07-27  1999           Say My Name
# 4  Red Hot Chili Peppers   1999-06-08  1999       Californication
#
#                  track_id  popularity  acousticness  danceability  \
# 0  1KGi9sZVMeszgZOWivFpxs          81        0.0251         0.743
# 1  2m1hi0nfMR9vdGC8UcrnwU          80        0.0103         0.434
# 2  3cfOd4CMv2snFaKAnMdnvK          81        0.0319         0.731
# 3  7H6ev70Weq6DdpZyyTmUXk          78        0.2730         0.713
# 4  48UPSzbZjgc449aqz8bxox          82        0.0021         0.592
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       214400   0.675          0.000717    8    0.0685    -4.267     0
# ...

# %%
music_genre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201707 entries, 0 to 201706
# Data columns (total 20 columns):
# artist_name         201707 non-null object
# release_date        201707 non-null object
# year                201707 non-null object
# track_name          201707 non-null object
# track_id            201707 non-null object
# popularity          201707 non-null int64
# acousticness        201707 non-null float64
# danceability        201707 non-null float64
# duration_ms         201707 non-null int64
# energy              201707 non-null float64
# instrumentalness    201707 non-null float64
# key                 201707 non-null int64
# liveness            201707 non-null float64
# loudness            201707 non-null float64
# mode                201707 non-null int64
# speechiness         201707 non-null float64
# tempo               201707 non-null float64
# time_signature      201707 non-null int64
# valence             201707 non-null float64
# ...

# %%
accept = pd.DataFrame()
accept = music_genre[(music_genre['danceability'] >= 0.3) & (music_genre['danceability'] <= 0.8) & (music_genre['acousticness'] >= 0) &
               (music_genre['acousticness'] <= 0.4) & (music_genre['energy'] >= 0.3) & (music_genre['energy'] <= 1) & (music_genre['loudness'] >= -20) &
               (music_genre['instrumentalness'] <= 0.8) & (music_genre['tempo'] >= 50) & (music_genre['tempo'] <= 200) & (music_genre['liveness'] <= 0.4) &
               (music_genre['duration_ms'] <= 400000) & (music_genre['duration_ms'] >= 100000) & (music_genre['speechiness'] <= 0.2)]
                                                                                                   
accept
# Out:
#                   artist_name release_date  year                   track_name  \
# 0                         TLC   1999-02-23  1999                    No Scrubs
# 2                 Smash Mouth   1999-01-01  1999                     All Star
# 3             Destiny's Child   1999-07-27  1999                  Say My Name
# 4       Red Hot Chili Peppers   1999-06-08  1999              Californication
# 5                   blink-182   1999-06-01  1999         What's My Age Again?
# ...                       ...          ...   ...                          ...
# 201692           Hayden James   2019-06-14  2019              Better Together
# 201700                 R.E.M.   2019-11-01  2019  Crush With Eyeliner - Remix
# 201701       Cali Y El Dandee   2019-02-13  2019                   Ay Corazón
# 201703          Reese LAFLARE   2019-11-08  2019                   Masquerade
# 201705         Greyson Chance   2019-11-08  2019                        Boots
#
# ...

# %%
tracks = accept[(accept.Genres == 'pop') |(accept.Genres == 'rock') | (accept.Genres == 'metal') | (accept.Genres == 'hip hop') | 
                (accept.Genres == 'rap') | (accept.Genres == 'country') | (accept.Genres == 'r&b') | (accept.Genres == 'alternative') | (accept.Genres == 'indie') | 
                (accept.Genres == 'edm') | (accept.Genres == 'idm') |(accept.Genres == 'jazz') |(accept.Genres == 'folk') |(accept.Genres == 'reggae') ]
tracks.head()
# Out:
#              artist_name release_date  year            track_name  \
# 0                    TLC   1999-02-23  1999             No Scrubs
# 2            Smash Mouth   1999-01-01  1999              All Star
# 3        Destiny's Child   1999-07-27  1999           Say My Name
# 4  Red Hot Chili Peppers   1999-06-08  1999       Californication
# 5              blink-182   1999-06-01  1999  What's My Age Again?
#
#                  track_id  popularity  acousticness  danceability  \
# 0  1KGi9sZVMeszgZOWivFpxs          81        0.0251         0.743
# 2  3cfOd4CMv2snFaKAnMdnvK          81        0.0319         0.731
# 3  7H6ev70Weq6DdpZyyTmUXk          78        0.2730         0.713
# 4  48UPSzbZjgc449aqz8bxox          82        0.0021         0.592
# 5  4LJhJ6DQS7NwE7UKtvcM52          77        0.0126         0.391
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       214400   0.675          0.000717    8    0.0685    -4.267     0
# ...

# %%
tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60586 entries, 0 to 201705
# Data columns (total 20 columns):
# artist_name         60586 non-null object
# release_date        60586 non-null object
# year                60586 non-null object
# track_name          60586 non-null object
# track_id            60586 non-null object
# popularity          60586 non-null int64
# acousticness        60586 non-null float64
# danceability        60586 non-null float64
# duration_ms         60586 non-null int64
# energy              60586 non-null float64
# instrumentalness    60586 non-null float64
# key                 60586 non-null int64
# liveness            60586 non-null float64
# loudness            60586 non-null float64
# mode                60586 non-null int64
# speechiness         60586 non-null float64
# tempo               60586 non-null float64
# time_signature      60586 non-null int64
# valence             60586 non-null float64
# Genres              60586 non-null object
# ...

# %%
sns.pairplot(tracks, 
             x_vars = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness', 'key', 'liveness',
                       'loudness', 'mode', 'speechiness', 'tempo', 'time_signature', 'valence'],
             y_vars = ['popularity'], 
             kind = 'reg', plot_kws = {'line_kws':{'color':'pink'},'scatter_kws': {'alpha' : 0.01}})

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
plt.scatter(tracks.danceability, tracks.popularity)
plt.title('linearity check')
plt.show()

# %%
# plt.scatter(tracks.Genres, tracks.popularity)
# plt.title('linearity check')
# plt.show()

# %%
f = 'popularity ~ danceability'
model = ols(formula = f, data = tracks).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             popularity   R-squared:                       0.022
# Model:                            OLS   Adj. R-squared:                  0.022
# Method:                 Least Squares   F-statistic:                     1368.
# Date:                Wed, 27 Nov 2019   Prob (F-statistic):          3.04e-296
# Time:                        10:27:04   Log-Likelihood:            -2.3883e+05
# No. Observations:               60586   AIC:                         4.777e+05
# Df Residuals:                   60584   BIC:                         4.777e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# ...

# %%
f = 'popularity ~ loudness'
model = ols(formula = f, data = tracks).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             popularity   R-squared:                       0.009
# Model:                            OLS   Adj. R-squared:                  0.009
# Method:                 Least Squares   F-statistic:                     525.0
# Date:                Wed, 27 Nov 2019   Prob (F-statistic):          1.09e-115
# Time:                        10:27:04   Log-Likelihood:            -2.3925e+05
# No. Observations:               60586   AIC:                         4.785e+05
# Df Residuals:                   60584   BIC:                         4.785e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     47.1871      0.145    325.603      0.000      46.903      47.471
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso, Ridge, LinearRegression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# scaler = MinMaxScaler()
# scaled_values = scaler.fit_transform(tracks) 
# tracks.loc[:,:] = scaled_values

# %%
# def normalize(tracks):
#     result = tracks.copy()
#     for feature_name in tracks.columns:
#         max_value = tracks[feature_name].max()
#         min_value = tracks[feature_name].min()
#         result[feature_name] = (tracks[feature_name] - min_value) / (max_value - min_value)
#     return result

# %%
column_names_to_normalize = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness',
                             'liveness', 'loudness', 'speechiness', 'tempo', 'valence']
column_names_to_not_normalize = [x for x in list(tracks) if x not in column_names_to_normalize ]

# %%
tracks['popularity'].astype(str).astype(int)
y = tracks[["popularity"]]
X = tracks.drop(column_names_to_not_normalize, axis=1)

scale = MinMaxScaler()
transformed = scale.fit_transform(X)
X = pd.DataFrame(transformed, columns = X.columns)

# %%
# Perform test train split
X_train , X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=12)

ridge = Ridge(alpha=1)
ridge.fit(X_train, y_train)

# lasso = Lasso(alpha=1)
# lasso.fit(X_train, y_train)

lin = LinearRegression()
lin.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Create predictions for training and test sets
y_h_ridge_train = ridge.predict(X_train)
y_h_ridge_test = ridge.predict(X_test)

# y_h_lasso_train = np.reshape(lasso.predict(X_train)
# y_h_lasso_test = np.reshape(lasso.predict(X_test)

y_h_lin_train = lin.predict(X_train)
y_h_lin_test = lin.predict(X_test)

# %%
print('Train Error Ridge Model', np.sum((y_train - y_h_ridge_train)**2))
print('Test Error Ridge Model', np.sum((y_test - y_h_ridge_test)**2))
print('\n')

# print('Train Error Lasso Model', np.sum((y_train - y_h_lasso_train)**2))
# print('Test Error Lasso Model', np.sum((y_test - y_h_lasso_test)**2))
# print('\n')

print('Train Error Unpenalized Linear Model', np.sum((y_train - lin.predict(X_train))**2))
print('Test Error Unpenalized Linear Model', np.sum((y_test - lin.predict(X_test))**2))
# Out:
# Train Error Ridge Model popularity    6.132055e+06
# dtype: float64
# Test Error Ridge Model popularity    2.646644e+06
# dtype: float64
#
#
# Train Error Unpenalized Linear Model popularity    6.132052e+06
# dtype: float64
# Test Error Unpenalized Linear Model popularity    2.646703e+06
# dtype: float64

# %%
print('Ridge parameter coefficients:', ridge.coef_)
# print('Lasso parameter coefficients:', lasso.coef_)
print('Linear model parameter coefficients:', lin.coef_)
# Out:
# Ridge parameter coefficients: [[ 1.2664008   9.77238611 -8.36867009 -7.84929106 -2.36911569 -0.80310901
#   26.05093162  1.65192169  2.21441907 -8.43260336]]
# Linear model parameter coefficients: [[ 1.26537085  9.77558569 -8.37242766 -7.88842683 -2.35942209 -0.80276435
#   26.16494712  1.65372652  2.21773852 -8.43347076]]

# %%
# plt.scatter(tracks.Genres, tracks.popularity)
# plt.title('linearity check')
# plt.show()

# %%
# plt.scatter(tracks.year, tracks.popularity)
# plt.show()

# %%
# plt.scatter(tracks.Genres, tracks.tempo)
# plt.show()

# %%
from pandas import Series

# %%
tracks.groupby('year')['acousticness'].mean()
# Out:
# year
# 1999    0.092287
# 2000    0.094486
# 2001    0.087047
# 2002    0.087991
# 2003    0.084188
# 2004    0.089348
# 2005    0.087349
# 2006    0.082587
# 2007    0.082006
# 2008    0.083853
# 2009    0.076751
# 2010    0.078781
# 2011    0.073509
# 2012    0.074905
# 2013    0.078662
# 2014    0.085528
# 2015    0.091371
# 2016    0.099023
# 2017    0.107384
# 2018    0.116496
# 2019    0.113049
# Name: acousticness, dtype: float64

# %%
tracks.groupby('year')['acousticness'].mean().plot(figsize=(14,4))
plt.show()

# %%
tracks.groupby('year')['danceability'].mean()
# Out:
# year
# 1999    0.566938
# 2000    0.568266
# 2001    0.569483
# 2002    0.562789
# 2003    0.550993
# 2004    0.550514
# 2005    0.556900
# 2006    0.554818
# 2007    0.558433
# 2008    0.556754
# 2009    0.554409
# 2010    0.564012
# 2011    0.556182
# 2012    0.565960
# 2013    0.567179
# 2014    0.575159
# 2015    0.585577
# 2016    0.592908
# 2017    0.609385
# 2018    0.620827
# 2019    0.625238
# Name: danceability, dtype: float64

# %%
tracks.groupby('year')['danceability'].mean().plot(figsize=(14,4))
plt.show()

# %%
tracks.groupby('year')['instrumentalness'].mean()
# Out:
# year
# 1999    0.058360
# 2000    0.060698
# 2001    0.056557
# 2002    0.056037
# 2003    0.049634
# 2004    0.051254
# 2005    0.057007
# 2006    0.048887
# 2007    0.042313
# 2008    0.047548
# 2009    0.047065
# 2010    0.047934
# 2011    0.053482
# 2012    0.048927
# 2013    0.048043
# 2014    0.050765
# 2015    0.043914
# 2016    0.039934
# 2017    0.030313
# 2018    0.022459
# 2019    0.020215
# Name: instrumentalness, dtype: float64

# %%
tracks.groupby('year')['instrumentalness'].mean().plot(figsize=(14,4))
plt.show()

# %%
tracks.groupby('year')['loudness'].mean()
# Out:
# year
# 1999   -6.931246
# 2000   -6.858655
# 2001   -6.461448
# 2002   -6.308299
# 2003   -6.059291
# 2004   -5.946135
# 2005   -5.995733
# 2006   -5.755694
# 2007   -5.755267
# 2008   -5.687924
# 2009   -5.652614
# 2010   -5.588862
# 2011   -5.638031
# 2012   -5.673868
# 2013   -5.790925
# 2014   -5.921942
# 2015   -5.962871
# 2016   -6.009798
# 2017   -6.086260
# 2018   -5.993331
# 2019   -5.870599
# Name: loudness, dtype: float64

# %%
tracks.groupby('year')['loudness'].mean().plot(figsize=(14,4))
plt.show()

# %%
tracks.groupby('year')['tempo'].mean()
# Out:
# year
# 1999    121.127284
# 2000    120.912726
# 2001    119.885791
# 2002    121.820778
# 2003    123.839352
# 2004    124.244489
# 2005    124.338745
# 2006    123.545482
# 2007    124.345886
# 2008    126.898631
# 2009    126.914423
# 2010    125.881881
# 2011    124.950304
# 2012    125.348918
# 2013    124.505832
# 2014    124.656757
# 2015    122.459488
# 2016    120.962373
# 2017    122.117557
# 2018    123.096558
# 2019    121.852433
# Name: tempo, dtype: float64

# %%
tracks.groupby('year')['tempo'].mean().plot(figsize=(14,4))
plt.show()

# %%
# tracks.groupby('year')['acousticness','danceability', 'instrumentalness', 'loudness'].mean().plot(figsize=(14,4))
# plt.show()

# %%
final_tracks = tracks[['year', 'acousticness', 'danceability', 'instrumentalness', 'loudness']]
final_tracks.head()
# Out:
#    year  acousticness  danceability  instrumentalness  loudness
# 0  1999        0.0251         0.743          0.000717    -4.267
# 2  1999        0.0319         0.731          0.000000    -5.881
# 3  1999        0.2730         0.713          0.000000    -3.525
# 4  1999        0.0021         0.592          0.001650    -2.788
# 5  1999        0.0126         0.391          0.000378    -7.419

# %%
# gtrends = final_tracks
# gtrends.columns = ['year', 'acousticness', 'danceability', 'instrumentalness', 'loudness']
# gtrends.year = pd.to_datetime(gtrends.year)
# gtrends.set_index('year', inplace=True)
# gtrends.plot(figsize=(18,6))
# plt.xlabel('year', fontsize=14)

# %%
dance_tracks = tracks[['release_date', 'danceability']]
dance_tracks
# Out:
#        release_date  danceability
# 0        1999-02-23         0.743
# 2        1999-01-01         0.731
# 3        1999-07-27         0.713
# 4        1999-06-08         0.592
# 5        1999-06-01         0.391
# ...             ...           ...
# 201681   2019-03-20         0.750
# 201692   2019-06-14         0.759
# 201700   2019-11-01         0.559
# 201703   2019-11-08         0.764
# 201705   2019-11-08         0.440
#
# [60586 rows x 2 columns]

# %%
dance_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 60586 entries, 0 to 201705
# Data columns (total 2 columns):
# release_date    60586 non-null object
# danceability    60586 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 1.4+ MB

# %%
dance_tracks['datetime'] = pd.to_datetime(dance_tracks['release_date'], format = ('%Y-%m-%d'), errors = 'coerce')
dance_tracks = dance_tracks.set_index('datetime')
dance_tracks.head()
# Out:
# /Users/mahimakaushiva/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#            release_date  danceability
# datetime
# 1999-02-23   1999-02-23         0.743
# 1999-01-01   1999-01-01         0.731
# 1999-07-27   1999-07-27         0.713
# 1999-06-08   1999-06-08         0.592
# 1999-06-01   1999-06-01         0.391

# %%
dance_tracks = dance_tracks.drop(columns = ['release_date'], axis = 1)
dance_tracks
# Out:
#             danceability
# datetime
# 1999-02-23         0.743
# 1999-01-01         0.731
# 1999-07-27         0.713
# 1999-06-08         0.592
# 1999-06-01         0.391
# ...                  ...
# 2019-03-20         0.750
# 2019-06-14         0.759
# 2019-11-01         0.559
# 2019-11-08         0.764
# 2019-11-08         0.440
#
# [60586 rows x 1 columns]

# %%
dance_tracks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 60586 entries, 1999-02-23 to 2019-11-08
# Data columns (total 1 columns):
# danceability    60586 non-null float64
# dtypes: float64(1)
# memory usage: 946.7 KB

# %%
dance_tracks['danceability'].resample('1m').mean()
# Out:
# datetime
# 1999-01-31    0.563261
# 1999-02-28    0.572714
# 1999-03-31    0.563992
# 1999-04-30    0.558928
# 1999-05-31    0.559446
#                 ...
# 2019-07-31    0.632237
# 2019-08-31    0.627722
# 2019-09-30    0.625479
# 2019-10-31    0.618428
# 2019-11-30    0.621148
# Freq: M, Name: danceability, Length: 251, dtype: float64

# %%
dance_tracks['danceability'].resample('1y').mean().plot(figsize=(14,4))
plt.show()

# %%
# df = dance_tracks['danceability'].resample('1m').mean()
# df

# %%
# series = dance_tracks.series(TS, index = datetime)

# %%
# from statsmodels.graphics.tsaplots import plot_pacf
# from statsmodels.graphics.tsaplots import plot_acf

# fig, ax = plt.subplots(figsize=(16,3))
# plot_acf(series,ax=ax, lags=40);

# fig, ax = plt.subplots(figsize=(16,3))
# plot_pacf(series,ax=ax, lags=40);

# %%
#splitting into train and test
# df

# %%
# df[-5:]

# %%
genres = tracks.groupby('Genres')['popularity'].mean()
genres = pd.DataFrame(genres)
genres
# Out:
#              popularity
# Genres
# alternative   40.883949
# country       42.162795
# edm           50.069478
# folk          38.055092
# hip hop       46.987184
# idm           45.816092
# indie         42.708052
# jazz          37.327035
# metal         41.466558
# pop           47.601078
# r&b           43.910603
# rap           49.412992
# reggae        42.950216
# rock          40.395254

# %%
old_names = ['Genres', 'popularity'] 
new_names = ['genre', 'mean_pop']
genres.rename(columns=dict(zip(old_names, new_names)), inplace=True)
genres
# Out:
#               mean_pop
# Genres
# alternative  40.883949
# country      42.162795
# edm          50.069478
# folk         38.055092
# hip hop      46.987184
# idm          45.816092
# indie        42.708052
# jazz         37.327035
# metal        41.466558
# pop          47.601078
# r&b          43.910603
# rap          49.412992
# reggae       42.950216
# rock         40.395254

# %%
Genres = tracks.groupby('Genres')['popularity'].median()
Genres = pd.DataFrame(Genres)
Genres
# Out:
#              popularity
# Genres
# alternative        40.0
# country            41.0
# edm                50.0
# folk               37.0
# hip hop            47.0
# idm                45.5
# indie              41.0
# jazz               36.0
# metal              40.0
# pop                47.0
# r&b                44.0
# rap                49.0
# reggae             42.0
# rock               39.0

# %%
old_names = ['Genres', 'popularity'] 
new_names = ['genre', 'median_pop']
Genres.rename(columns=dict(zip(old_names, new_names)), inplace=True)
Genres
# Out:
#              median_pop
# Genres
# alternative        40.0
# country            41.0
# edm                50.0
# folk               37.0
# hip hop            47.0
# idm                45.5
# indie              41.0
# jazz               36.0
# metal              40.0
# pop                47.0
# r&b                44.0
# rap                49.0
# reggae             42.0
# rock               39.0

# %%
df = pd.concat([genres, Genres], axis = 1, sort = False)
df
# Out:
#               mean_pop  median_pop
# Genres
# alternative  40.883949        40.0
# country      42.162795        41.0
# edm          50.069478        50.0
# folk         38.055092        37.0
# hip hop      46.987184        47.0
# idm          45.816092        45.5
# indie        42.708052        41.0
# jazz         37.327035        36.0
# metal        41.466558        40.0
# pop          47.601078        47.0
# r&b          43.910603        44.0
# rap          49.412992        49.0
# reggae       42.950216        42.0
# rock         40.395254        39.0

# %%
DF = df.sort_values(by=['mean_pop', 'median_pop'], ascending=True)
DF
# Out:
#               mean_pop  median_pop
# Genres
# jazz         37.327035        36.0
# folk         38.055092        37.0
# rock         40.395254        39.0
# alternative  40.883949        40.0
# metal        41.466558        40.0
# country      42.162795        41.0
# indie        42.708052        41.0
# reggae       42.950216        42.0
# r&b          43.910603        44.0
# idm          45.816092        45.5
# hip hop      46.987184        47.0
# pop          47.601078        47.0
# rap          49.412992        49.0
# edm          50.069478        50.0

# %%
DF.plot(kind = 'bar', figsize = (14,4))
plt.show()
